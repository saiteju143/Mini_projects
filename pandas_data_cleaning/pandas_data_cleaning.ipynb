C094,ABHISHEK,37,Hyderabad,abhishek2@gmail.com,3700,5
C095,roopa,33, HYDERABAD ,roopa2@gmail.com,2500,4
C096,Tarun,28,Bangalore,tarun2@gmail.com,1900,3
C097,MANASA,30,bangalore,manasa2@gmail.com,2300,5
C098,Krishna,36,Delhi,krishna2@gmail.com,3400,4
C099,Asha,27, delhi ,asha2@gmail.com,1400,3
C100,Rajesh,43,Chennai,rajesh2@gmail.com,4800,5
C101,  Teju ,33,hyderabad,TEJU@GMAIL.COM,2500,5
C102,rahul,28, HYDERABAD ,rahul3@gmail.com,1500,4
C103,,31,Chennai,emptyname@gmail.com,2200,4
C104,  Anu ,29,,anu@gmail.com,,5
C105,Ravi,thirty,Mumbai,ravi3@gmail.com,abc,good"""

# %%
with open("data.txt" , "w") as file:
    file.write(data)

# %%
import pandas as pd
df=pd.read_csv("data.txt")

# %%
df
# Out:
#     customer_id     name     age         city                email  \
# 0          C001    Teju       33    hyderabad       TEJU@GMAIL.COM
# 1          C002    RAHUL      28   HYDERABAD       rahul@gmail.com
# 2          C003    Priya     abc    Bangalore      priya@gmail.com
# 3          C004     anil      35    HYDERABAD       anil@gmail.com
# 4          C005     SITA      29          NaN       sita@gmail.com
# ..          ...      ...     ...          ...                  ...
# 100        C101    Teju       33    hyderabad       TEJU@GMAIL.COM
# 101        C102    rahul      28   HYDERABAD      rahul3@gmail.com
# 102        C103      NaN      31      Chennai  emptyname@gmail.com
# 103        C104     Anu       29          NaN        anu@gmail.com
# 104        C105     Ravi  thirty       Mumbai      ravi3@gmail.com
#
#     purchase_amount rating
# 0              2500      5
# 1              1500      4
# 2              2000      5
# 3               abc      4
# ...

# %%
print("Messy Dataframe: ", df.shape)
# Out:
# Messy Dataframe:  (105, 7)

# %%
df.isnull()
# Out:
#      customer_id   name    age   city  email  purchase_amount  rating
# 0          False  False  False  False  False            False   False
# 1          False  False  False  False  False            False   False
# 2          False  False  False  False  False            False   False
# 3          False  False  False  False  False            False   False
# 4          False  False  False   True  False            False   False
# ..           ...    ...    ...    ...    ...              ...     ...
# 100        False  False  False  False  False            False   False
# 101        False  False  False  False  False            False   False
# 102        False   True  False  False  False            False   False
# 103        False  False  False   True  False             True   False
# 104        False  False  False  False  False            False   False
#
# [105 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# customer_id        0
# name               1
# age                4
# city               2
# email              1
# purchase_amount    1
# rating             0
# dtype: int64

# %%
df.dropna()
# Out:
#     customer_id     name     age         city              email  \
# 0          C001    Teju       33    hyderabad     TEJU@GMAIL.COM
# 1          C002    RAHUL      28   HYDERABAD     rahul@gmail.com
# 2          C003    Priya     abc    Bangalore    priya@gmail.com
# 3          C004     anil      35    HYDERABAD     anil@gmail.com
# 5          C006     Ravi      31      Chennai     ravi@gmail.com
# ..          ...      ...     ...          ...                ...
# 98         C099     Asha      27       delhi     asha2@gmail.com
# 99         C100   Rajesh      43      Chennai  rajesh2@gmail.com
# 100        C101    Teju       33    hyderabad     TEJU@GMAIL.COM
# 101        C102    rahul      28   HYDERABAD    rahul3@gmail.com
# 104        C105     Ravi  thirty       Mumbai    ravi3@gmail.com
#
#     purchase_amount rating
# 0              2500      5
# 1              1500      4
# 2              2000      5
# 3               abc      4
# 5              2200      5
# ...

# %%
df["age"]=pd.to_numeric(df["age"],errors="coerce")
df["purchase_amount"]=pd.to_numeric(df["purchase_amount"],errors="coerce")
df["rating"]=pd.to_numeric(df["rating"],errors="coerce")

df["customer_id"]=df["customer_id"].fillna("Unknown")
df["name"]=df["name"].fillna("Unknown")
df["city"]=df["city"].fillna("Unknown")
df["email"]=df["email"].fillna("Unknown")
df["age"]=df["age"].fillna(df["age"].mean().round(1))
df["purchase_amount"]=df["purchase_amount"].fillna(df["age"].mean().round(1))
df["rating"]=df["rating"].fillna(df["age"].mean().round(1))

# %%
df
# Out:
#     customer_id     name       age         city                email  \
# 0          C001    Teju   33.00000    hyderabad       TEJU@GMAIL.COM
# 1          C002    RAHUL  28.00000   HYDERABAD       rahul@gmail.com
# 2          C003    Priya  31.22449    Bangalore      priya@gmail.com
# 3          C004     anil  35.00000    HYDERABAD       anil@gmail.com
# 4          C005     SITA  29.00000      Unknown       sita@gmail.com
# ..          ...      ...       ...          ...                  ...
# 100        C101    Teju   33.00000    hyderabad       TEJU@GMAIL.COM
# 101        C102    rahul  28.00000   HYDERABAD      rahul3@gmail.com
# 102        C103  Unknown  31.00000      Chennai  emptyname@gmail.com
# 103        C104     Anu   29.00000      Unknown        anu@gmail.com
# 104        C105     Ravi  31.22449       Mumbai      ravi3@gmail.com
#
#      purchase_amount    rating
# 0         2500.00000   5.00000
# 1         1500.00000   4.00000
# 2         2000.00000   5.00000
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 100    False
# 101    False
# 102    False
# 103    False
# 104    False
# Length: 105, dtype: bool

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#     customer_id     name       age         city                email  \
# 0          C001    Teju   33.00000    hyderabad       TEJU@GMAIL.COM
# 1          C002    RAHUL  28.00000   HYDERABAD       rahul@gmail.com
# 2          C003    Priya  31.22449    Bangalore      priya@gmail.com
# 3          C004     anil  35.00000    HYDERABAD       anil@gmail.com
# 4          C005     SITA  29.00000      Unknown       sita@gmail.com
# ..          ...      ...       ...          ...                  ...
# 100        C101    Teju   33.00000    hyderabad       TEJU@GMAIL.COM
# 101        C102    rahul  28.00000   HYDERABAD      rahul3@gmail.com
# 102        C103  Unknown  31.00000      Chennai  emptyname@gmail.com
# 103        C104     Anu   29.00000      Unknown        anu@gmail.com
# 104        C105     Ravi  31.22449       Mumbai      ravi3@gmail.com
#
#      purchase_amount    rating
# 0         2500.00000   5.00000
# 1         1500.00000   4.00000
# 2         2000.00000   5.00000
# ...

# %%
df["age"]=df["age"].astype(int)
df["purchase_amount"]=df["purchase_amount"].astype(int)
df["rating"]=df["rating"].astype(int)

# %%
df["name"]=df["name"].str.strip()
df["city"]=df["name"].str.title()

# %%
df["email"]=df["name"].str.strip().str.lower()
df["customer_id	"]=df["customer_id	"].str.upper()
